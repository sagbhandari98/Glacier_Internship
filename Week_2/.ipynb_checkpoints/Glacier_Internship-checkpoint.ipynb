# %% [markdown]
# ## Project Description:
# The objective is to assist a private firm in the US cab industry to identify the most suitable company for investment. This involves conducting market research and analyzing data to determine the optimal investment choice between two cab companies.
#
# Data Analysis Steps:
#
# 1. **Data Set Investigation and Joining:** Explore the provided datasets and perform necessary data joins.
#
# 2. **Exploratory Data Analysis (EDA) and Visualization:** Conduct EDA to gain insights into the data and visualize key trends and patterns.
#
# 3. **Hypothesis Testing:** Perform hypothesis tests to make informed decisions based on statistical analysis.
#
# ## Datasets Provided:
#
# 1. **Cab_Data.csv:** Contains transaction details for two cab companies.
# 2. **Customer_ID.csv:** A mapping table linking customer demographic details to unique identifiers.
# 3. **Transaction_ID.csv:** A mapping table linking transactions to customers and payment modes.
# 4. **City.csv:** Includes a list of US cities along with their populations and the number of cab users.

# %% [markdown]
# ## Part 1: Importing Libraries and Dataset

# %% [markdown]
# ### 1.1 Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1.2 Importing datasets

# %%
cab_data = pd.read_csv("C:/Users/sagri/Downloads/Cab_Data.csv")
transaction_data = pd.read_csv("C:/Users/sagri/Downloads/Transaction_ID.csv")
customer_data = pd.read_csv("C:/Users/sagri/Downloads/Customer_ID.csv")
city_data= pd.read_csv("C:/Users/sagri/Downloads/City.csv")

# %% [markdown]
# ***1-Investigation the first dataset(cab_data)***

# %%
cab_data
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# ...

# %%
cab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB

# %%
cab_data.isnull().sum()
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64

# %%
import datetime
#  convert the 'Date' column to datetime format
def ordinary_date(x):
    temp = datetime.datetime(1900, 1, 1)
    delta = datetime.timedelta(x)
    return temp+delta

# %%
cab_data['Date of Travel'] = cab_data['Date of Travel'].apply(lambda x:ordinary_date(x))
cab_data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-01-10  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-08  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-04  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-09  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-05  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
cab_data['Company'].value_counts()
# Out:
# Yellow Cab    274681
# Pink Cab       84711
# Name: Company, dtype: int64

# %%
cab_data['City'].value_counts()
# Out:
# NEW YORK NY       99885
# CHICAGO IL        56625
# LOS ANGELES CA    48033
# WASHINGTON DC     43737
# BOSTON MA         29692
# SAN DIEGO CA      20488
# SILICON VALLEY     8519
# SEATTLE WA         7997
# ATLANTA GA         7557
# DALLAS TX          7017
# MIAMI FL           6454
# AUSTIN TX          4896
# ORANGE COUNTY      3982
# DENVER CO          3825
# NASHVILLE TN       3010
# SACRAMENTO CA      2367
# PHOENIX AZ         2064
# TUCSON AZ          1931
# PITTSBURGH PA      1313
# Name: City, dtype: int64

# %%
cab_data['City'].unique()
# Out:
# array(['ATLANTA GA', 'AUSTIN TX', 'BOSTON MA', 'CHICAGO IL', 'DALLAS TX',
#        'DENVER CO', 'LOS ANGELES CA', 'MIAMI FL', 'NASHVILLE TN',
#        'NEW YORK NY', 'ORANGE COUNTY', 'PHOENIX AZ', 'PITTSBURGH PA',
#        'SACRAMENTO CA', 'SAN DIEGO CA', 'SEATTLE WA', 'SILICON VALLEY',
#        'TUCSON AZ', 'WASHINGTON DC'], dtype=object)

# %%
# Add 'Profit' column
cab_data['Profit'] = cab_data["Price Charged"] - cab_data["Cost of Trip"]

# Display the first few rows
cab_data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     2016-01-10  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-08  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-04  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-09  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-05  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip  Profit
# 0         370.95       313.635  57.315
# 1         358.52       334.854  23.666
# 2         125.20        97.632  27.568
# 3         377.40       351.602  25.798
# 4         114.62        97.776  16.844

# %%
cab_data.describe()
# Out:
#        Transaction ID   KM Travelled  Price Charged   Cost of Trip  \
# count    3.593920e+05  359392.000000  359392.000000  359392.000000
# mean     1.022076e+07      22.567254     423.443311     286.190113
# std      1.268058e+05      12.233526     274.378911     157.993661
# min      1.000001e+07       1.900000      15.600000      19.000000
# 25%      1.011081e+07      12.000000     206.437500     151.200000
# 50%      1.022104e+07      22.440000     386.360000     282.480000
# 75%      1.033094e+07      32.960000     583.660000     413.683200
# max      1.044011e+07      48.000000    2048.030000     691.200000
#
#               Profit
# count  359392.000000
# mean      137.253198
# std       160.311840
# min      -220.060000
# 25%        28.012000
# 50%        81.962000
# 75%       190.030000
# max      1463.966000

# %% [markdown]
# ***2-Investigation the second dataset(transaction_data)***

# %%
transaction_data
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
transaction_data.isnull().sum()
# Out:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64

# %%
transaction_data['Payment_Mode'].value_counts()
# Out:
# Card    263991
# Cash    176107
# Name: Payment_Mode, dtype: int64

# %%
transaction_data.describe()
# Out:
#        Transaction ID    Customer ID
# count    4.400980e+05  440098.000000
# mean     1.022006e+07   23619.513120
# std      1.270455e+05   21195.549816
# min      1.000001e+07       1.000000
# 25%      1.011004e+07    3530.000000
# 50%      1.022006e+07   15168.000000
# 75%      1.033008e+07   43884.000000
# max      1.044011e+07   60000.000000

# %% [markdown]
# ***3-Investigation the third dataset(customer_data)***

# %%
customer_data
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
customer_data.isnull().sum()
# Out:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64

# %%
customer_data['Gender'].value_counts()
# Out:
# Male      26562
# Female    22609
# Name: Gender, dtype: int64

# %%
customer_data.describe()
# Out:
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %% [markdown]
# ***4-Investigation the fourth dataset(city_data)***

# %%
city_data
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
city_data.isnull().sum()
# Out:
# City          0
# Population    0
# Users         0
# dtype: int64

# %%
# Remove commas and convert to integer
city_data['Population'] = city_data['Population'].str.replace(',', '').astype('int64')
city_data['Users'] = city_data['Users'].str.replace(',', '').astype('int64')

# Display updated information
city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     int64
#  2   Users       20 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 608.0+ bytes

# %% [markdown]
# ## Part 2: Merge and Visualize the Whole Dataset

# %% [markdown]
# ### 2.1: Merge the Whole Dataset

# %%
# Perform join
merged_data = pd.merge(transaction_data, customer_data, on='Customer ID', how='inner')
merged_data = pd.merge(merged_data, cab_data, on='Transaction ID', how='inner')

# Handle missing values if any
merged_data.dropna(inplace=True)

# Validate results
print(merged_data.head())
# Out:
#    Transaction ID  Customer ID Payment_Mode Gender  Age  Income (USD/Month)  \
# 0        10000011        29290         Card   Male   28               10813
# 1        10351127        29290         Cash   Male   28               10813
# 2        10412921        29290         Card   Male   28               10813
# 3        10000012        27703         Card   Male   27                9237
# 4        10320494        27703         Card   Male   27                9237
#
#   Date of Travel     Company        City  KM Travelled  Price Charged  \
# 0     2016-01-10    Pink Cab  ATLANTA GA         30.45         370.95
# 1     2018-07-23  Yellow Cab  ATLANTA GA         26.19         598.70
# 2     2018-11-25  Yellow Cab  ATLANTA GA         42.55         792.05
# 3     2016-01-08    Pink Cab  ATLANTA GA         28.62         358.52
# 4     2018-04-23  Yellow Cab  ATLANTA GA         36.38         721.10
#
#    Cost of Trip    Profit
# 0      313.6350   57.3150
# 1      317.4228  281.2772
# ...

# %%
merged_data
# Out:
#         Transaction ID  Customer ID Payment_Mode  Gender  Age  \
# 0             10000011        29290         Card    Male   28
# 1             10351127        29290         Cash    Male   28
# 2             10412921        29290         Card    Male   28
# 3             10000012        27703         Card    Male   27
# 4             10320494        27703         Card    Male   27
# ...                ...          ...          ...     ...  ...
# 359387        10439790        38520         Card  Female   42
# 359388        10439799        12490         Cash    Male   33
# 359389        10439838        41414         Card    Male   38
# 359390        10439840        41677         Cash    Male   23
# 359391        10439846        39761         Card  Female   32
#
#         Income (USD/Month) Date of Travel     Company            City  \
# 0                    10813     2016-01-10    Pink Cab      ATLANTA GA
# 1                    10813     2018-07-23  Yellow Cab      ATLANTA GA
# ...

# %%
# Perform join
final_data = pd.merge(merged_data, city_data, on='City')

# Handle missing values if any
final_data.dropna(inplace=True)

# Validate results
print(final_data.head())
# Out:
#    Transaction ID  Customer ID Payment_Mode Gender  Age  Income (USD/Month)  \
# 0        10000011        29290         Card   Male   28               10813
# 1        10351127        29290         Cash   Male   28               10813
# 2        10412921        29290         Card   Male   28               10813
# 3        10000012        27703         Card   Male   27                9237
# 4        10320494        27703         Card   Male   27                9237
#
#   Date of Travel     Company        City  KM Travelled  Price Charged  \
# 0     2016-01-10    Pink Cab  ATLANTA GA         30.45         370.95
# 1     2018-07-23  Yellow Cab  ATLANTA GA         26.19         598.70
# 2     2018-11-25  Yellow Cab  ATLANTA GA         42.55         792.05
# 3     2016-01-08    Pink Cab  ATLANTA GA         28.62         358.52
# 4     2018-04-23  Yellow Cab  ATLANTA GA         36.38         721.10
#
#    Cost of Trip    Profit  Population  Users
# ...

# %%
final_data
# Out:
#         Transaction ID  Customer ID Payment_Mode  Gender  Age  \
# 0             10000011        29290         Card    Male   28
# 1             10351127        29290         Cash    Male   28
# 2             10412921        29290         Card    Male   28
# 3             10000012        27703         Card    Male   27
# 4             10320494        27703         Card    Male   27
# ...                ...          ...          ...     ...  ...
# 359387        10307228        51406         Cash  Female   29
# 359388        10319775        51406         Cash  Female   29
# 359389        10347676        51406         Card  Female   29
# 359390        10358624        51406         Cash  Female   29
# 359391        10370709        51406         Card  Female   29
#
#         Income (USD/Month) Date of Travel     Company           City  \
# 0                    10813     2016-01-10    Pink Cab     ATLANTA GA
# 1                    10813     2018-07-23  Yellow Cab     ATLANTA GA
# ...

# %%
# Convert 'Date' attribute to datetime format
final_data['Date'] = pd.to_datetime(final_data['Date of Travel'])

# Extract year from 'Date' attribute and create a new attribute 'Year'
final_data['Year'] = final_data['Date'].dt.year

# Display the DataFrame with the new 'Year' attribute
print(final_data.head())
# Out:
#    Transaction ID  Customer ID Payment_Mode Gender  Age  Income (USD/Month)  \
# 0        10000011        29290         Card   Male   28               10813
# 1        10351127        29290         Cash   Male   28               10813
# 2        10412921        29290         Card   Male   28               10813
# 3        10000012        27703         Card   Male   27                9237
# 4        10320494        27703         Card   Male   27                9237
#
#   Date of Travel     Company        City  KM Travelled  Price Charged  \
# 0     2016-01-10    Pink Cab  ATLANTA GA         30.45         370.95
# 1     2018-07-23  Yellow Cab  ATLANTA GA         26.19         598.70
# 2     2018-11-25  Yellow Cab  ATLANTA GA         42.55         792.05
# 3     2016-01-08    Pink Cab  ATLANTA GA         28.62         358.52
# 4     2018-04-23  Yellow Cab  ATLANTA GA         36.38         721.10
#
#    Cost of Trip    Profit  Population  Users       Date  Year
# ...

# %% [markdown]
# ### 2.2 : EDA and Visualization

# %%
print("Data Info:")
print(final_data.info())
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction ID      359392 non-null  int64
#  1   Customer ID         359392 non-null  int64
#  2   Payment_Mode        359392 non-null  object
#  3   Gender              359392 non-null  object
#  4   Age                 359392 non-null  int64
#  5   Income (USD/Month)  359392 non-null  int64
#  6   Date of Travel      359392 non-null  datetime64[ns]
#  7   Company             359392 non-null  object
#  8   City                359392 non-null  object
#  9   KM Travelled        359392 non-null  float64
#  10  Price Charged       359392 non-null  float64
#  11  Cost of Trip        359392 non-null  float64
#  12  Profit              359392 non-null  float64
#  13  Population          359392 non-null  int64
# ...

# %%
print("\nSummary Statistics:")
final_data.describe()
# Out:
# Summary Statistics:
#        Transaction ID    Customer ID            Age  Income (USD/Month)  \
# count    3.593920e+05  359392.000000  359392.000000       359392.000000
# mean     1.022076e+07   19191.652115      35.336705        15048.822937
# std      1.268058e+05   21012.412463      12.594234         7969.409482
# min      1.000001e+07       1.000000      18.000000         2000.000000
# 25%      1.011081e+07    2705.000000      25.000000         8424.000000
# 50%      1.022104e+07    7459.000000      33.000000        14685.000000
# 75%      1.033094e+07   36078.000000      42.000000        21035.000000
# max      1.044011e+07   60000.000000      65.000000        35000.000000
#
#         KM Travelled  Price Charged   Cost of Trip         Profit  \
# count  359392.000000  359392.000000  359392.000000  359392.000000
# mean       22.567254     423.443311     286.190113     137.253198
# std        12.233526     274.378911     157.993661     160.311840
# ...

# %%
sns.pairplot(final_data.head(1000), hue = 'Company')

# %%
print("\nMissing Values:")
print(final_data.isnull().sum())
# Out:
# Missing Values:
# Transaction ID        0
# Customer ID           0
# Payment_Mode          0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# Date of Travel        0
# Company               0
# City                  0
# KM Travelled          0
# Price Charged         0
# Cost of Trip          0
# Profit                0
# Population            0
# Users                 0
# Date                  0
# Year                  0
# dtype: int64

# %% [markdown]
# ## Analysis of Transaction

# %%
# Create a 2x2 grid of plots
fig = plt.figure(figsize=(15, 12))

# Total Transactions by Company
fig.add_subplot(2, 2, 1)
group = final_data.groupby('Company')['Transaction ID'].count().reset_index()
ax1 = sns.barplot(data=group, x='Company', y='Transaction ID', palette="magma")
ax1.set_title("Company-wise Transaction Volume", fontsize=14)
ax1.set_xlabel("Company", fontsize=12)
ax1.set_ylabel("Transactions Count", fontsize=12)
ax1.bar_label(ax1.containers[0])

# Total Transactions by Gender for each Company
fig.add_subplot(2, 2, 2)
group = final_data.groupby(by=['Company', 'Gender'])['Transaction ID'].count().reset_index()
ax2 = sns.barplot(data=group, x="Company", hue="Gender", y='Transaction ID', palette="magma")
ax2.set_title("Gender-wise Transaction Distribution", fontsize=14)
ax2.set_xlabel("Company", fontsize=12)
ax2.set_ylabel("Transactions Count", fontsize=12)
for container in ax2.containers:
    ax2.bar_label(container)

# Total Transactions by Payment Mode for each Company
fig.add_subplot(2, 2, 3)
group = final_data.groupby(by=['Company', 'Payment_Mode'])['Transaction ID'].count().reset_index()
ax3 = sns.barplot(data=group, x="Company", hue="Payment_Mode", y='Transaction ID', palette="magma")
ax3.set_title("Transactions by Payment Mode", fontsize=14)
ax3.set_xlabel("Company", fontsize=12)
ax3.set_ylabel("Transactions Count", fontsize=12)
for container in ax3.containers:
    ax3.bar_label(container)

# Total Profit by Company
fig.add_subplot(2, 2, 4)
group = final_data.groupby(by=['Company'])['Profit'].sum().reset_index()
ax4 = sns.barplot(data=group, x="Company", y='Profit', palette="magma")
ax4.set_title("Profit Distribution Across Companies", fontsize=14)
ax4.set_xlabel("Company", fontsize=12)
ax4.set_ylabel("Total Profit (USD)", fontsize=12)
ax4.bar_label(ax4.containers[0])

# Adjust layout for better spacing
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# **Graph 1: Company-wise Transaction Volume, Gender-wise Transaction Distribution by Company, Transactions by Payment Mode for Each Company, Total Profit by Company**

# %% [markdown]
# ## Analysis  City-Wise

# %%
# Create a 2x1 grid of plots
fig, axs = plt.subplots(2, 1, figsize=(15, 15))

# Total Population by City
population = final_data.groupby("City").agg({"Population":"count"}).sort_values('Population').reset_index()
ax1 = sns.barplot(data=population, x='Population', y='City', palette="magma", ax=axs[0])
ax1.set_title("Total Population by City", fontsize=14)
ax1.set_xlabel("Total Population", fontsize=12)
ax1.set_ylabel("City", fontsize=12)

# Total Income by City
group_income = final_data.groupby('City')['Income (USD/Month)'].sum().reset_index()
ax2 = sns.barplot(data=group_income, x='Income (USD/Month)', y='City', palette="magma", ax=axs[1])
ax2.set_title("Total Income by City", fontsize=14)
ax2.set_xlabel("Total Income (USD)", fontsize=12)
ax2.set_ylabel("City", fontsize=12)

# Adjust layout for better spacing
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# **Graph 2: Total Population and Income by City**

# %%
# Filter data for Yellow and Pink cab companies
filtered_data = final_data[final_data['Company'].isin(['Yellow Cab', 'Pink Cab'])]

# Group by City and Company to get the count of transactions
grouped_data = filtered_data.groupby(['City', 'Company'])['Transaction ID'].count().reset_index()

# Create a pivot table for easier plotting
pivot_data = grouped_data.pivot(index='City', columns='Company', values='Transaction ID').fillna(0)

# Plotting
plt.figure(figsize=(15, 10))
colors = sns.color_palette("magma", n_colors=2)
ax = pivot_data.plot(kind='bar', stacked=False, color=colors, figsize=(15, 10))

# Set plot title and labels
plt.title('Customer Presence of Yellow and Pink Cab Services City-wise', fontsize=16)
plt.xlabel('City', fontsize=14)
plt.ylabel('Number of Transactions', fontsize=14)

# Add legend
plt.legend(title='Company', title_fontsize='13', fontsize='12')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Graph 3: Customer presence of Yellow and Pink cab services city-wise**

# %%
plt.figure(figsize=(15, 10))

# Grouping the data
group = final_data.groupby(['Company', 'City'])['Profit'].sum().sort_values(ascending=False).reset_index()

# Plotting
ax = sns.barplot(data=group, x='City', y='Profit', hue='Company', palette='magma')

# Customizing the plot
plt.title("Profit in Cities by Company", fontsize=16)
plt.xlabel("City", fontsize=14)
plt.ylabel("Total Profit (USD)", fontsize=14)
plt.xticks(rotation=45, ha='right')

# Adding legend with appropriate title
plt.legend(title='Company', title_fontsize='13', fontsize='12')

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Graph 4: Company Profit CIty-Wise**

# %%
# Create a scatter plot
plt.figure(figsize=(10, 8))
sns.scatterplot(data=final_data, x='KM Travelled', y='Price Charged', hue='Company', palette='magma')
plt.title('Kilometers Travelled vs. Price Charged by Company', fontsize=16)
plt.xlabel('Kilometers Travelled', fontsize=14)
plt.ylabel('Price Charged', fontsize=14)
plt.legend(title='Company', title_fontsize='13', fontsize='12')

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Grouping the data by year and kilometers traveled
group_km =final_data.groupby(['Year', 'Company'])['KM Travelled'].sum().reset_index()

# Filtering data for Pink Cab
pink_cab_km = group_km[group_km['Company'] == 'Pink Cab']

# Filtering data for Yellow Cab
yellow_cab_km = group_km[group_km['Company'] == 'Yellow Cab']

# Plotting the grouped bar plot
plt.figure(figsize=(12, 6))

# Plotting Yellow Cab kilometers traveled
bar3 = sns.barplot(x='Year', y='KM Travelled', data=yellow_cab_km, color='mediumaquamarine')

# Plotting Pink Cab kilometers traveled on top of Yellow Cab kilometers traveled
bar4 = sns.barplot(x='Year', y='KM Travelled', data=pink_cab_km, color='lightseagreen', ci=None)

# Adding legend

km_legend = mpatches.Patch(color='mediumaquamarine', label='Yellow Cab KM Traveled')

km_legend2 = mpatches.Patch(color='lightseagreen', label='Pink Cab KM Traveled')
plt.legend(handles=[ km_legend, km_legend2])

# Adding labels to the bars

for bar in bar3.containers:
    bar3.bar_label(bar, label_type='center')

for bar in bar4.containers:
    bar4.bar_label(bar, label_type='center')

# Setting labels and title
plt.ylabel("Profit / KM Traveled")
plt.title("Comparison of Profit and KM Traveled Between Yellow Cab and Pink Cab by Year")

# Show the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
